# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tomas Rozo**
#
# I aspire to be a data scientist

# %% [markdown]
# *I'm interested in data science because I love to manipulate, study and visualize data to extract value from it*

# %% [markdown]
# ### The next cell will have a function that returns a reversed string

# %%
def reverse_string(x):
    return x[::-1]
reverse_string('Hello world')
# Out:
# 'dlrow olleH'

# %% [markdown]
# 1. one
# 2. two
# 3. three
# 4. four
# 5. five
